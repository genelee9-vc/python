# %% [markdown]
# # Logistic Regression models are for CLASSIFICATION not Regression
# ## Data preparation and cleaning steps are the same for regression or classification models
# ## Classification used to predict categorical data (what is this image of, what is the type)
# ## Classification models plot the probability Y of X
# ## p(yi) = 1/1+ e-(A+Bxi)
# #### A is the intercept; B is the regression coefficient; e is the constant 2.71828 (Euler's number)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('Data_Files/housing.csv')
housing_data.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 420     -122.26     37.89                  52         3706           531.0
# 2047    -119.72     36.72                  15         1713           246.0
# 1730    -122.35     37.98                  34         3756           726.0
# 2276    -119.79     36.80                  27         2462           484.0
# 1847    -122.28     37.91                  41         3009           482.0
#
#       population  households  median_income  median_house_value  \
# 420         1205         504         6.6828              370900
# 2047         766         232         6.8162              127200
# 1730        2237         686         3.7562              132900
# 2276         852         449         3.3200              124700
# 1847        1053         490         5.8280              324400
#
#      ocean_proximity
# 420         NEAR BAY
# 2047          INLAND
# 1730        NEAR BAY
# 2276          INLAND
# 1847        NEAR BAY

# %%
housing_data.shape
# Out:
# (2382, 10)

# %%
housing_data = housing_data.dropna()

# %%
housing_data.shape
# Out:
# (2365, 10)

# %%
housing_data.loc[housing_data['median_house_value']==500001].count()
# Out:
# longitude             28
# latitude              28
# housing_median_age    28
# total_rooms           28
# total_bedrooms        28
# population            28
# households            28
# median_income         28
# median_house_value    28
# ocean_proximity       28
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value']== 500001].index)

# %%
housing_data.shape
# Out:
# (2337, 10)

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#pd.get_dummies converts to one hot form
housing_data = pd.get_dummies(housing_data, columns=['ocean_proximity'])

# %%
housing_data.sample(10)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2089    -119.79     36.76                  52         2408           498.0
# 1399    -122.08     37.96                  21         9135          1534.0
# 1922    -120.81     38.89                  17         1438           324.0
# 1504    -122.03     37.94                  21         5541           776.0
# 648     -122.13     37.72                  25         1134           153.0
# 596     -122.08     37.70                  32         2718           447.0
# 1175    -121.57     39.48                  15          202            54.0
# 2241    -119.81     36.83                  10         5780           922.0
# 1968    -120.70     38.69                  13         4492           821.0
# 1140    -121.59     39.74                  17         1646           330.0
#
#       population  households  median_income  median_house_value  \
# 2089        1361         465         2.1055               61300
# 1399        3748        1502         6.0859              266000
# 1922         675         268         2.9444              119300
# 1504        2214         737         5.5777              279300
# 648          340         171         6.5095              371200
# 596         1156         410         5.2497              259300
# 1175         145          40         0.8252               42500
# 2241        2712         883         5.6445              135500
# 1968        2093         734         4.0709              151700
# 1140         750         344         2.3798               83800
#
#       ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 2089                          0                       1
# 1399                          0                       0
# 1922                          0                       1
# 1504                          0                       0
# 648                           0                       0
# 596                           0                       0
# 1175                          0                       1
# 2241                          0                       1
# 1968                          0                       1
# 1140                          0                       1
#
#       ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 2089                       0                         0
# 1399                       0                         1
# 1922                       0                         0
# 1504                       0                         1
# 648                        0                         1
# 596                        0                         1
# 1175                       0                         0
# 2241                       0                         0
# 1968                       0                         0
# 1140                       0                         0
#
#       ocean_proximity_NEAR OCEAN
# 2089                           0
# 1399                           0
# 1922                           0
# 1504                           0
# 648                            0
# 596                            0
# 1175                           0
# 2241                           0
# 1968                           0
# 1140                           0

# %%
housing_data.shape
# Out:
# (2337, 14)

# %%
median = housing_data['median_house_value'].median()
median
# Out:
# 156600.0

# %%
housing_data['above_median'] = (housing_data['median_house_value'] - median) > 0

# %%
housing_data.sample(15)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1356    -121.92     38.02                  16         1840           355.0
# 2186    -120.00     36.70                  33         1902           370.0
# 1205    -121.71     39.42                  21         1432           284.0
# 769     -122.09     37.65                  35         1184           200.0
# 1600    -122.12     37.89                  30         3227           733.0
# 950     -121.93     37.72                  26         2806           459.0
# 2063    -119.73     36.59                  31         1551           296.0
# 1647    -121.82     37.81                  12         4711           659.0
# 506     -122.29     37.84                  35         1872           419.0
# 2365    -119.50     36.74                  20         1089           208.0
# 1233    -120.34     38.23                  10         3757           722.0
# 1570    -122.02     37.84                  34         1879           265.0
# 22      -122.27     37.84                  52         2436           541.0
# 2105    -119.76     36.75                  39         2233           563.0
# 2098    -119.77     36.76                  43         1623           294.0
#
#       population  households  median_income  median_house_value  \
# 1356        1288         338         4.2067              125000
# 2186        1168         358         2.6852               70800
# 1205         862         275         2.2813               57600
# 769          572         194         4.7143              193800
# 1600        1260         684         4.1250              257100
# 950         1453         444         4.9107              213800
# 2063        1058         287         3.3438               92600
# 1647        2089         621         8.3209              485400
# 506         1017         414         2.2106              132500
# 2365         531         212         4.5938              106900
# 1233         546         223         3.7500              121400
# 1570         729         263         7.7072              443800
# 22          1015         478         1.7250              113900
# 2105        2031         491         1.8641               50800
# 2098         781         272         1.8690               56000
#
#       ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 1356                          0                       1
# 2186                          0                       1
# 1205                          0                       1
# 769                           0                       0
# 1600                          0                       0
# 950                           1                       0
# 2063                          0                       1
# 1647                          0                       1
# 506                           0                       0
# 2365                          0                       1
# 1233                          0                       1
# 1570                          0                       0
# 22                            0                       0
# 2105                          0                       1
# 2098                          0                       1
#
#       ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 1356                       0                         0
# 2186                       0                         0
# 1205                       0                         0
# 769                        0                         1
# 1600                       0                         1
# 950                        0                         0
# 2063                       0                         0
# 1647                       0                         0
# 506                        0                         1
# 2365                       0                         0
# 1233                       0                         0
# 1570                       0                         1
# 22                         0                         1
# 2105                       0                         0
# 2098                       0                         0
#
#       ocean_proximity_NEAR OCEAN  above_median
# 1356                           0         False
# 2186                           0         False
# 1205                           0         False
# 769                            0          True
# 1600                           0          True
# 950                            0          True
# 2063                           0         False
# 1647                           0          True
# 506                            0         False
# 2365                           0         False
# 1233                           0         False
# 1570                           0          True
# 22                             0         False
# 2105                           0         False
# 2098                           0         False

# %%
#Setting up features and Y-values (labels) of our classification model
X = housing_data.drop(['median_house_value', 'above_median'], axis=1)
Y = housing_data['above_median'] #Y value just becomes True or False

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2) #80/20 train test split

# %%
x_train.shape, x_test.shape
# Out:
# ((1869, 13), (468, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((1869,), (468,))

# %%
#Ready to perform logisitic regression to classify our data
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(solver='liblinear').fit(x_train,y_train) #Fit function kick starts the training process. Liblinear solver is good for small datasets and binary classification

# %%
print("Training_score:", logistic_model.score(x_train,y_train))
# Out:
# Training_score: 0.8651685393258427

# %% [markdown]
# ### For Classification models/problems, the default score is determined by accuracy
# #### 86.5% of the predictions were correct on TRAINING data. How does it perform on TEST data?

# %%
y_pred = logistic_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'Predicted':y_pred, 'Actual':y_test})
df_pred_actual.head(15)
# Out:
#       Predicted  Actual
# 1305      False   False
# 31        False   False
# 195       False   False
# 24        False   False
# 1734       True   False
# 601        True    True
# 1462      False    True
# 1864       True   False
# 2157      False   False
# 999        True    True
# 1906      False   False
# 2247      False   False
# 56        False   False
# 69        False   False
# 1594       True    True

# %%
from sklearn.metrics import accuracy_score
print("Testing_score:", accuracy_score(y_test,y_pred))
# Out:
# Testing_score: 0.8568376068376068

# %% [markdown]
# ### Testing Score of 85.65% only slightly lower than Training Score of 96.52%
